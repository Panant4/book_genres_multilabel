# %%
import numpy as np
import pandas as pd
import re
from sklearn.svm import LinearSVC,SVC
import sklearn
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import f1_score,accuracy_score,recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import SGDClassifier
from KaggleWord2VecUtility import KaggleWord2VecUtility
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction import DictVectorizer
from pandas import ExcelWriter
from pandas import ExcelFile
import matplotlib.pyplot as plt
import seaborn as sns
from nltk import bigrams
from nltk.stem.porter import *
import xlrd
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn import preprocessing
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn import model_selection
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import cross_validate
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import classification_report
from skmultilearn.problem_transform import BinaryRelevance
from sklearn.naive_bayes import GaussianNB
from skmultilearn.problem_transform import ClassifierChain
from skmultilearn.problem_transform import LabelPowerset
from skmultilearn.adapt import MLkNN,BRkNNaClassifier,BRkNNbClassifier




df = pd.read_csv('/home/pramod/Downloads/Book_Dataset_clean.csv')

result = []

genre=df["Genre"][0:300]

summ=df["Summary"][0:300]

for xi in genre:
    abc = re.sub(r'"/[a-zA-Z/0-9 ]+": ',"",xi)
    abc = re.sub(r'[{}\"\"]+',"",abc)
    abc = re.sub(r'\\u00e0',"a",abc)
    abc = re.sub(r', ',",",abc)
    result.append(abc)
    
genre_arr = np.array([np.array(xi.split(",")) for xi in result])

clean_summaries=[]
for i in range(0,len(summ)):
    clean_summaries.append(" ".join(KaggleWord2VecUtility.review_to_wordlist(summ[i], False,False)))
clean_summaries = np.array(clean_summaries)



mlb = MultiLabelBinarizer()
Y = mlb.fit_transform(genre_arr)


#reduce the number of classes

classifier = Pipeline([
    ('vectorizer', TfidfVectorizer()),
    #('tfidf', TfidfTransformer()),
    ('clf', LabelPowerset(RandomForestClassifier()))])

print clean_summaries.shape
print Y.shape
classifier = classifier.fit(clean_summaries,Y)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-27-49c25b10def2> in <module>()
#      77 from sklearn.ensemble import RandomForestClassifier
#      78 from skmultilearn.problem_transform import LabelPowerset
# ---> 79 from skmultilearn.cluster import IGraphLabelCooccurenceClusterer
#      80 from skmultilearn.ensemble import LabelSpacePartitioningClassifier
#      81
#
# /home/pramod/anaconda2/lib/python2.7/site-packages/skmultilearn/cluster/__init__.py in <module>()
#       6 from .base import LabelSpaceClustererBase
#       7 from .base import LabelCooccurenceClustererBase
# ----> 8 from .graphtool import GraphToolCooccurenceClusterer
#       9 from .igraph import IGraphLabelCooccurenceClusterer
#      10 from .matrix import MatrixLabelSpaceClusterer
#
# /home/pramod/anaconda2/lib/python2.7/site-packages/skmultilearn/cluster/graphtool.py in <module>()
#       5 import copy
#       6 import numpy as np
# ----> 7 import graph_tool.all as gt
#       8
#       9
#
# ImportError: No module named graph_tool.all

# %%
cv = ShuffleSplit(n_splits=2, test_size=0.2)

y_pred=cross_val_predict(estimator=classifier, X=clean_summaries, y=Y,cv=5,n_jobs=-1)


print(classification_report(Y, y_pred))

print accuracy_score(Y,y_pred)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00         1
#           1       0.00      0.00      0.00         3
#           2       0.00      0.00      0.00         3
#           3       0.00      0.00      0.00         7
#           4       0.00      0.00      0.00         1
#           5       0.33      0.06      0.11        16
#           6       0.00      0.00      0.00         2
#           7       0.00      0.00      0.00         1
#           8       0.00      0.00      0.00         1
#           9       0.00      0.00      0.00         2
#          10       0.00      0.00      0.00         5
#          11       0.00      0.00      0.00         4
#          12       0.00      0.00      0.00         4
#          13       0.00      0.00      0.00         1
#          14       0.00      0.00      0.00         3
#          15       0.00      0.00      0.00         1
#          16       0.17      0.19      0.18        57
#          17       0.00      0.00      0.00         2
#          18       0.00      0.00      0.00         7
#          19       0.00      0.00      0.00         1
#          20       0.00      0.00      0.00         1
#          21       0.00      0.00      0.00         2
#          22       0.00      0.00      0.00         2
#          23       0.00      0.00      0.00         1
#          24       0.00      0.00      0.00         1
#          25       0.50      0.20      0.29         5
#          26       0.00      0.00      0.00         2
#          27       0.00      0.00      0.00         4
#          28       0.00      0.00      0.00         2
#          29       0.00      0.00      0.00        14
#          30       0.00      0.00      0.00         1
#          31       0.00      0.00      0.00         6
#          32       0.00      0.00      0.00         1
#          33       0.00      0.00      0.00         1
#          34       0.00      0.00      0.00         3
#          35       0.00      0.00      0.00         1
#          36       0.35      0.11      0.17        62
#          37       0.00      0.00      0.00         1
#          38       0.66      0.63      0.64       196
#          39       0.00      0.00      0.00         1
#          40       0.00      0.00      0.00         9
#          41       0.00      0.00      0.00         1
#          42       0.00      0.00      0.00         2
#          43       0.00      0.00      0.00         3
#          44       0.00      0.00      0.00         2
#          45       0.00      0.00      0.00         5
#          46       0.00      0.00      0.00         5
#          47       0.00      0.00      0.00         2
#          48       0.00      0.00      0.00        20
#          49       0.00      0.00      0.00         6
#          50       0.00      0.00      0.00         1
#          51       0.00      0.00      0.00         1
#          52       0.00      0.00      0.00         1
#          53       0.00      0.00      0.00         2
#          54       0.00      0.00      0.00         1
#          55       0.00      0.00      0.00         3
#          56       0.00      0.00      0.00         1
#          57       0.00      0.00      0.00         1
#          58       0.00      0.00      0.00         1
#          59       0.00      0.00      0.00         1
#          60       1.00      0.07      0.12        15
#          61       0.00      0.00      0.00         5
#          62       0.00      0.00      0.00         1
#          63       0.29      0.32      0.30        82
#          64       0.00      0.00      0.00         9
#          65       0.00      0.00      0.00         1
#          66       0.00      0.00      0.00         3
#          67       0.00      0.00      0.00         1
#          68       0.00      0.00      0.00         1
#          69       0.00      0.00      0.00         7
#          70       0.00      0.00      0.00         1
#          71       0.00      0.00      0.00         1
#          72       0.00      0.00      0.00         4
#          73       0.00      0.00      0.00         2
#          74       0.00      0.00      0.00         1
#          75       0.00      0.00      0.00         5
#          76       0.00      0.00      0.00        12
#          77       0.00      0.00      0.00        16
#          78       0.00      0.00      0.00         4
#          79       0.45      0.57      0.50       116
#          80       0.00      0.00      0.00         4
#          81       0.00      0.00      0.00         1
#          82       0.00      0.00      0.00         1
#          83       0.00      0.00      0.00         1
#          84       0.00      0.00      0.00         1
#          85       0.00      0.00      0.00         1
#          86       0.61      0.68      0.64       157
#          87       0.00      0.00      0.00         1
#          88       0.00      0.00      0.00         6
#          89       0.00      0.00      0.00         1
#          90       0.25      0.08      0.12        12
#          91       0.00      0.00      0.00         2
#          92       0.00      0.00      0.00         6
#          93       0.00      0.00      0.00         1
#          94       0.00      0.00      0.00         1
#          95       0.00      0.00      0.00         1
#          96       0.00      0.00      0.00         3
#          97       0.00      0.00      0.00         2
#          98       0.00      0.00      0.00         5
#          99       0.00      0.00      0.00         2
#         100       0.00      0.00      0.00         2
#         101       0.00      0.00      0.00         1
#         102       0.00      0.00      0.00         1
#
# avg / total       0.36      0.34      0.34       997
#
# 0.0533333333333

# %%
import numpy as np
import pandas as pd
import re
from sklearn.svm import LinearSVC,SVC
import sklearn
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import f1_score,accuracy_score,recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import SGDClassifier
from KaggleWord2VecUtility import KaggleWord2VecUtility
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction import DictVectorizer
from pandas import ExcelWriter
from pandas import ExcelFile
import matplotlib.pyplot as plt
import seaborn as sns
from nltk import bigrams
from nltk.stem.porter import *
import xlrd
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn import preprocessing
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn import model_selection
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import cross_validate
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import classification_report
from skmultilearn.problem_transform import BinaryRelevance
from sklearn.naive_bayes import GaussianNB
from skmultilearn.problem_transform import ClassifierChain
from skmultilearn.problem_transform import LabelPowerset
from skmultilearn.adapt import MLkNN,BRkNNaClassifier,BRkNNbClassifier




df = pd.read_csv('/home/pramod/Downloads/Book_Dataset_clean.csv')

result = []

genre=df["Genre"][0:300]
for xi in genre:
    abc = re.sub(r'"/[a-zA-Z/0-9 ]+": ',"",xi)
    abc = re.sub(r'[{}\"\"]+',"",abc)
    abc = re.sub(r'\\u00e0',"a",abc)
    abc = re.sub(r', ',",",abc)
    result.append(abc)
    
genre_arr = np.array([np.array(xi.split(",")) for xi in result])

for genre in genre_arr:
    for i in xrange(0,len(genre)):
        if genre[i]=='Speculative fiction':
            genre[i]=str(genre[i])
            genre[i].replace(genre[i],'Fiction')
            
print genre_arr
# Out:
# [ array(['Roman a clef', 'Satire', "Children's literature",
#        'Speculative fiction', 'Fiction'],
#       dtype='|S21')
#  array(['Science Fiction', 'Novella', 'Speculative fiction',
#        'Utopian and dystopian fiction', 'Satire', 'Fiction'],
#       dtype='|S29')
#  array(['Existentialism', 'Fiction', 'Absurdist fiction', 'Novel'],
#       dtype='|S17')
#  array(['Hard science fiction', 'Science Fiction', 'Speculative fiction',
#        'Fantasy', 'Fiction'],
#       dtype='|S20')
#  array(['War novel', 'Roman a clef'],
#       dtype='|S12')
#  array(["Children's literature", 'Fantasy', 'Speculative fiction',
#        'Bildungsroman', 'Fiction'],
#       dtype='|S21')
#  array(['Science Fiction', 'Speculative fiction'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction'],
#       dtype='|S19')
#  array(['Speculative fiction', 'Fiction', 'Novel'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction', "Children's literature",
#        'Fiction'],
#       dtype='|S21')
#  array(['Satire', 'Bildungsroman', '/m/0g_jj: Picaresque novel'],
#       dtype='|S26')
#  array(['Science Fiction', 'Speculative fiction', "Children's literature",
#        'Fiction'],
#       dtype='|S21')
#  array(['Gothic fiction'],
#       dtype='|S14')
#  array(['Fiction'],
#       dtype='|S7')
#  array(['Science Fiction', 'Speculative fiction', 'Horror',
#        'Invasion literature', 'Mystery', 'Epistolary novel', 'Fantasy',
#        'Fiction', 'Gothic fiction'],
#       dtype='|S19')
#  array(['Parody', "Children's literature", 'Psychological novel', 'Satire',
#        'Farce', '/m/0g_jj: Picaresque novel', 'Fiction'],
#       dtype='|S26')
#  array(['Science Fiction', 'Speculative fiction', "Children's literature",
#        'Fiction', 'Novel'],
#       dtype='|S21')
#  array(['Philosophy', 'Science'],
#       dtype='|S10')
#  array(['Fiction'],
#       dtype='|S7')
#  array(['Fiction', 'Absurdist fiction', 'Novel'],
#       dtype='|S17')
#  array(['Science Fiction', "Children's literature", 'Speculative fiction',
#        'Utopian and dystopian fiction', 'Fiction', 'Dystopia'],
#       dtype='|S29')
#  array(['Fantasy', 'Fiction'],
#       dtype='|S7')
#  array(['Mystery', 'Detective fiction', 'Novel', 'Fiction', 'Suspense'],
#       dtype='|S17')
#  array(['Science Fiction', 'Speculative fiction', "Children's literature",
#        'Fiction'],
#       dtype='|S21')
#  array(['Historical fiction', 'Fiction', 'Novel'],
#       dtype='|S18')
#  array(['Fiction', 'Novella', 'Roman a clef'],
#       dtype='|S12')
#  array(['Science Fiction', 'Speculative fiction', 'Fiction'],
#       dtype='|S19')
#  array(['Satire', "Children's literature", 'Fiction', 'Adventure novel',
#        'Humour'],
#       dtype='|S21')
#  array(['Historical fiction', 'Fiction', 'Historical novel'],
#       dtype='|S18')
#  array(['Fiction', 'Novel'],
#       dtype='|S7')
#  array(['Science Fiction', 'Speculative fiction'],
#       dtype='|S19')
#  array(['Epistolary novel', 'Fiction'],
#       dtype='|S16')
#  array(['Sea story', 'Fiction', 'Adventure novel'],
#       dtype='|S15')
#  array(['Adventure novel'],
#       dtype='|S15')
#  array(['Cyberpunk', 'Science Fiction', 'Speculative fiction', 'Dystopia'],
#       dtype='|S19')
#  array(['Fiction', 'Novel'],
#       dtype='|S7')
#  array(['Business', 'Non-fiction', 'Economics', 'Anthropology', 'Sociology',
#        'Fiction'],
#       dtype='|S12')
#  array(['Science Fiction', 'Speculative fiction', 'Fiction', 'Dystopia'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction', 'Fiction', 'Dystopia'],
#       dtype='|S19')
#  array(['Science Fiction', 'Psychological novel', 'Speculative fiction',
#        'Roman a clef', 'Fiction', 'Dystopia'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction', 'Dystopia'],
#       dtype='|S19')
#  array(['Satire', 'Fiction', 'Romance novel', 'Novel'],
#       dtype='|S13')
#  array(['Fiction'],
#       dtype='|S7')
#  array(['Absurdist fiction'],
#       dtype='|S17')
#  array(['Science Fiction', 'Speculative fiction', 'Fiction', 'Novel'],
#       dtype='|S19')
#  array(['Hard science fiction', 'Science Fiction', 'Speculative fiction'],
#       dtype='|S20')
#  array(["Children's literature", 'Fiction', 'Romance novel', 'Novel'],
#       dtype='|S21')
#  array(['Science Fiction', 'Speculative fiction', 'Fantasy', 'Fiction'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction', 'Fiction'],
#       dtype='|S19')
#  array(['Poetry'],
#       dtype='|S6')
#  array(['Speculative fiction', "Children's literature", 'Fiction'],
#       dtype='|S21')
#  array(['Adventure novel', 'Speculative fiction', 'Fantasy', 'Fiction',
#        'Chivalric romance', 'High fantasy'],
#       dtype='|S19')
#  array(['Philosophy', 'Non-fiction'],
#       dtype='|S11')
#  array(['Science Fiction', "Children's literature", 'Speculative fiction',
#        'Romance novel', 'Fantasy', 'Fiction', 'Time travel', 'Dystopia',
#        'Scientific romance'],
#       dtype='|S21')
#  array(['Science Fiction', 'Speculative fiction', 'Novel'],
#       dtype='|S19')
#  array(['Gothic fiction', "Children's literature", 'Horror',
#        'Speculative fiction', 'Fiction'],
#       dtype='|S21')
#  array(['Science Fiction', 'Speculative fiction', 'Fantasy', 'Fiction'],
#       dtype='|S19')
#  array(['Crime Fiction', 'Mystery', 'Detective fiction', 'Novel'],
#       dtype='|S17')
#  array(["Children's literature", 'Juvenile fantasy', 'Adventure novel',
#        'Speculative fiction', 'Fantasy', 'Fiction'],
#       dtype='|S21')
#  array(['Speculative fiction', 'Fantasy', 'Religion'],
#       dtype='|S19')
#  array(['Epistolary novel', 'Inspirational', 'Speculative fiction',
#        'Satire', 'Fantasy', 'Fiction', 'Humour'],
#       dtype='|S19')
#  array(['Horror', 'Speculative fiction', 'Short story'],
#       dtype='|S19')
#  array(['Novel', 'Techno-thriller', "Children's literature", 'Fiction',
#        'Suspense'],
#       dtype='|S21')
#  array(['Thriller', 'Fiction', 'Novel'],
#       dtype='|S8')
#  array(['Thriller', 'Fiction', 'Novel'],
#       dtype='|S8')
#  array(['Science Fiction', 'Speculative fiction', "Children's literature",
#        'Fiction'],
#       dtype='|S21')
#  array(['Non-fiction', 'Science'],
#       dtype='|S11')
#  array(['Gothic fiction', 'Speculative fiction', 'Horror', 'Fiction'],
#       dtype='|S19')
#  array(['Speculative fiction'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction'],
#       dtype='|S19')
#  array(['Speculative fiction', 'Young adult literature', 'Fiction', 'Novel'],
#       dtype='|S22')
#  array(["Children's literature"],
#       dtype='|S21')
#  array(['Poetry', 'Drama', 'Fiction', 'Absurdist fiction', 'Play'],
#       dtype='|S17')
#  array(['Science Fiction', 'Speculative fiction', 'Fantasy', 'Fiction',
#        'Novel'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction'],
#       dtype='|S19')
#  array(['Science Fiction', "Children's literature", 'Speculative fiction',
#        'Utopian and dystopian fiction', 'Fiction', 'Dystopia'],
#       dtype='|S29')
#  array(['Fantasy', 'Fiction', 'Poetry'],
#       dtype='|S7')
#  array(['Poetry'],
#       dtype='|S6')
#  array(['/m/08w0_f: Albino bias', 'Science Fiction',
#        "Children's literature", 'Horror', 'Novel', 'Speculative fiction',
#        'Science', 'Fiction', 'Scientific romance'],
#       dtype='|S22')
#  array(['Science Fiction', "Children's literature", 'Novel',
#        'Adventure novel', 'Fiction', 'Scientific romance'],
#       dtype='|S21')
#  array(['Novel'],
#       dtype='|S5')
#  array(['Computer Science'],
#       dtype='|S16')
#  array(['Existentialism'],
#       dtype='|S14')
#  array(['Gothic fiction', 'Satire', 'Reference', 'Fiction', 'Romance novel'],
#       dtype='|S14')
#  array(['Poetry'],
#       dtype='|S6')
#  array(['Speculative fiction', 'Fantasy', 'High fantasy'],
#       dtype='|S19')
#  array(['Speculative fiction', 'Fantasy'],
#       dtype='|S19')
#  array(['Speculative fiction', 'Fantasy'],
#       dtype='|S19')
#  array(['Speculative fiction', 'Fantasy'],
#       dtype='|S19')
#  array(["Children's literature", 'Fiction', 'Adventure novel'],
#       dtype='|S21')
#  array(['Novel'],
#       dtype='|S5')
#  array(['Historical fiction', 'Drama', 'Fiction', 'Novel'],
#       dtype='|S18')
#  array(['Horror', 'Supernatural', 'Speculative fiction', 'Fantasy',
#        'Fiction', 'Gothic fiction'],
#       dtype='|S19')
#  array(['Science Fiction', 'Satire', 'Fantasy', 'Speculative fiction'],
#       dtype='|S19')
#  array(['Epistolary novel', 'Fiction'],
#       dtype='|S16')
#  array(['Fantasy', 'Comedy'],
#       dtype='|S7')
#  array(['Fiction', 'Novel'],
#       dtype='|S7')
#  array(['Science Fiction', 'Speculative fiction', 'Fiction', 'Novel'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction', 'Fantasy', 'Fiction'],
#       dtype='|S19')
#  array(['Literary fiction'],
#       dtype='|S16')
#  array(['History', 'Novel'],
#       dtype='|S7')
#  array(['Science Fiction', 'Speculative fiction', 'Fiction'],
#       dtype='|S19')
#  array(['Science Fiction', 'Fantasy', 'Fiction'],
#       dtype='|S15')
#  array(['Science Fiction', 'Speculative fiction', 'Fiction'],
#       dtype='|S19')
#  array(["Children's literature", 'Fiction', 'Novel'],
#       dtype='|S21')
#  array(['Speculative fiction'],
#       dtype='|S19')
#  array(['Self-help', 'Spirituality', 'Speculative fiction', 'Fiction',
#        'Novella'],
#       dtype='|S19')
#  array(['Vampire fiction', 'Science Fiction', 'Horror',
#        'Speculative fiction', 'Zombies in popular culture',
#        'Apocalyptic and post-apocalyptic fiction', 'Fiction',
#        '/m/09vxq_p: Catastrophic literature', 'Dystopia'],
#       dtype='|S40')
#  array(['Crime Fiction', 'Existentialism', 'Fiction', 'Absurdist fiction',
#        'Suspense'],
#       dtype='|S17')
#  array(['Alternate history', 'Science Fiction', 'Speculative fiction',
#        'Fantasy', 'Dystopia'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction', "Children's literature",
#        'Fiction'],
#       dtype='|S21')
#  array(['Science Fiction', 'Speculative fiction', 'Fantasy', 'Fiction'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction', "Children's literature",
#        'Fiction', 'Novel'],
#       dtype='|S21')
#  array(['Science Fiction', 'Speculative fiction', 'Fiction', 'Novel'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction', 'Fiction'],
#       dtype='|S19')
#  array(['Erotica'],
#       dtype='|S7')
#  array(['Science Fiction', 'Speculative fiction', 'Fiction'],
#       dtype='|S19')
#  array(['Spy fiction'],
#       dtype='|S11')
#  array(['Science Fiction', 'Speculative fiction', 'Techno-thriller',
#        'Mystery', 'Suspense', 'Fiction'],
#       dtype='|S19')
#  array(["Children's literature", 'Fantasy', 'Speculative fiction', 'Fiction'],
#       dtype='|S21')
#  array(['Autobiographical novel', 'Autobiography', 'Fiction', 'Memoir',
#        'Non-fiction'],
#       dtype='|S22')
#  array(['/m/09vxq_p: Catastrophic literature',
#        'Apocalyptic and post-apocalyptic fiction', 'Science Fiction',
#        'Speculative fiction', 'Fiction'],
#       dtype='|S40')
#  array(['Speculative fiction', 'Novel'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction', 'Fantasy', 'Comedy'],
#       dtype='|S19')
#  array(['Science Fiction', "Children's literature", 'Fantasy', 'Fiction'],
#       dtype='|S21')
#  array(['Cyberpunk', 'Science Fiction', 'Speculative fiction', 'Fiction',
#        'Postcyberpunk'],
#       dtype='|S19')
#  array(["Children's literature", 'Fiction'],
#       dtype='|S21')
#  array(["Children's literature", 'Fantasy', 'Speculative fiction',
#        'Absurdist fiction', 'Fiction'],
#       dtype='|S21')
#  array(['Science Fiction', 'Speculative fiction', 'Fantasy'],
#       dtype='|S19')
#  array(['Speculative fiction', 'Fantasy', "Children's literature"],
#       dtype='|S21')
#  array(['Speculative fiction', 'Fantasy', "Children's literature"],
#       dtype='|S21')
#  array(['Science Fiction', 'Speculative fiction'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction', 'Fantasy', 'Fiction'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction', "Children's literature",
#        'Fiction'],
#       dtype='|S21')
#  array(['Science Fiction', 'Speculative fiction', 'Fiction'],
#       dtype='|S19')
#  array(['Science Fiction', 'Fiction'],
#       dtype='|S15')
#  array(['Science Fiction', 'Speculative fiction', 'Fantasy', 'Fiction',
#        'Novel'],
#       dtype='|S19')
#  array(['Science Fiction', 'Fantasy', 'Fiction'],
#       dtype='|S15')
#  array(['Science Fiction', 'Speculative fiction', 'Fiction'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction'],
#       dtype='|S19')
#  array(['Speculative fiction', 'Fantasy', "Children's literature"],
#       dtype='|S21')
#  array(['Gothic fiction', 'Fiction', 'Novel'],
#       dtype='|S14')
#  array(['Novel', 'Social criticism', 'Romance novel', 'Fiction',
#        'Bildungsroman', 'Gothic fiction'],
#       dtype='|S16')
#  array(['Anti-war', 'War novel', 'Absurdist fiction', 'Historical fiction',
#        'Satire', 'Black comedy'],
#       dtype='|S18')
#  array(['Speculative fiction', "Children's literature", 'Fiction',
#        'Adventure novel', 'Novel'],
#       dtype='|S21')
#  array(['Thriller', 'Mystery', "Children's literature", 'Fiction',
#        'Suspense'],
#       dtype='|S21')
#  array(['Fiction', 'Historical novel'],
#       dtype='|S16')
#  array(["Children's literature", 'Reference', 'Novel', 'Comedy of manners',
#        'Romance novel', 'Comedy', 'Fiction'],
#       dtype='|S21')
#  array(["Children's literature", 'Fantasy', 'Speculative fiction', 'Fiction'],
#       dtype='|S21')
#  array(["Children's literature", 'Novel'],
#       dtype='|S21')
#  array(['Fiction', 'Novel'],
#       dtype='|S7')
#  array(['Fiction', 'Novel'],
#       dtype='|S7')
#  array(['Mystery', 'Novel', 'Fiction', 'Suspense'],
#       dtype='|S8')
#  array(['Science Fiction', 'Speculative fiction'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction', 'Fiction'],
#       dtype='|S19')
#  array(['Fiction'],
#       dtype='|S7')
#  array(['Science Fiction', 'Speculative fiction', 'Fiction', 'Dystopia',
#        'Novel'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction', 'Novel'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction', 'Fiction', 'Novel'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction', 'Fiction', 'Novel'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction'],
#       dtype='|S19')
#  array(['Science Fiction', 'Fantasy', 'Fiction', 'Novel'],
#       dtype='|S15')
#  array(['Science Fiction'],
#       dtype='|S15')
#  array(['Science Fiction', 'Speculative fiction', 'Novel'],
#       dtype='|S19')
#  array(['Science Fiction', "Children's literature", 'Speculative fiction',
#        'Mystery', 'Fantasy', 'Fiction'],
#       dtype='|S21')
#  array(['Science Fiction', 'Speculative fiction', "Children's literature",
#        'Fiction'],
#       dtype='|S21')
#  array(['Science Fiction', 'Speculative fiction', 'Fiction', 'Novel'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction', 'Fiction'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction', "Children's literature",
#        'Fiction'],
#       dtype='|S21')
#  array(['Science Fiction', 'Speculative fiction', 'Fiction'],
#       dtype='|S19')
#  array(['Science Fiction'],
#       dtype='|S15')
#  array(['Crime Fiction', 'Detective fiction', 'Mystery', 'Fiction',
#        'Hardboiled', 'Suspense'],
#       dtype='|S17')
#  array(['Western', 'Fiction', 'Adventure novel'],
#       dtype='|S15')
#  array(['Spy fiction', 'Fiction'],
#       dtype='|S11')
#  array(['Science Fiction', 'Spy fiction', 'Fiction'],
#       dtype='|S15')
#  array(['Spy fiction', 'Novel', '/m/0g_jj: Picaresque novel'],
#       dtype='|S26')
#  array(['Science Fiction', 'Fantasy', 'Fiction', 'Novel'],
#       dtype='|S15')
#  array(['Science Fiction', 'Speculative fiction', 'Fiction',
#        'Comic science fiction', 'Humour'],
#       dtype='|S21')
#  array(['Fiction', 'Novel'],
#       dtype='|S7')
#  array(['Fiction', 'Novel'],
#       dtype='|S7')
#  array(['Novel'],
#       dtype='|S5')
#  array(['Science Fiction', "Children's literature", 'Fantasy',
#        'Speculative fiction', 'Fiction'],
#       dtype='|S21')
#  array(['Autobiographical novel'],
#       dtype='|S22')
#  array(['Fantasy', 'Fiction', 'Romance novel', 'Novel'],
#       dtype='|S13')
#  array(['Fiction', 'Novel'],
#       dtype='|S7')
#  array(['Novel'],
#       dtype='|S5')
#  array(["Children's literature", 'Adventure novel', 'Speculative fiction',
#        'Fantasy', 'Non-fiction novel', 'Lost World', 'Fiction'],
#       dtype='|S21')
#  array(['Fiction'],
#       dtype='|S7')
#  array(['Psychological novel'],
#       dtype='|S19')
#  array(['Novella'],
#       dtype='|S7')
#  array(['Speculative fiction', 'Fantasy', 'Fiction', 'Novel'],
#       dtype='|S19')
#  array(['K\\u00fcnstlerroman', 'Fiction', 'Novel'],
#       dtype='|S18')
#  array(['Science Fiction', 'Speculative fiction',
#        '/m/09vxq_p: Catastrophic literature', 'Transhumanism'],
#       dtype='|S35')
#  array(['Science Fiction', "Children's literature", 'Fantasy',
#        'Speculative fiction', 'Fiction'],
#       dtype='|S21')
#  array(['Science Fiction', 'Biography', 'Speculative fiction', 'Fantasy',
#        'Fiction', 'Autobiography'],
#       dtype='|S19')
#  array(['Science Fiction', "Children's literature", 'Horror',
#        'Western fiction', 'Speculative fiction', 'Fantasy', 'Fiction'],
#       dtype='|S21')
#  array(['Science Fiction', "Children's literature", 'Horror',
#        'Western fiction', 'Speculative fiction', 'Western', 'Fantasy',
#        'Fiction'],
#       dtype='|S21')
#  array(['Autobiography'],
#       dtype='|S13')
#  array(['Novella'],
#       dtype='|S7')
#  array(['Science Fiction', "Children's literature", 'Horror',
#        'Speculative fiction', 'Fantasy', 'Fiction'],
#       dtype='|S21')
#  array(['Fantasy', 'Science Fiction', 'Speculative fiction', 'Horror',
#        'Fiction'],
#       dtype='|S19')
#  array(["Children's literature", 'Fantasy', 'Speculative fiction', 'Fiction'],
#       dtype='|S21')
#  array(['Thriller', "Children's literature", 'Horror',
#        'Speculative fiction', 'Fiction'],
#       dtype='|S21')
#  array(['Thriller', 'Speculative fiction', 'Horror'],
#       dtype='|S19')
#  array(['Fiction'],
#       dtype='|S7')
#  array(['Fantasy', 'Speculative fiction', 'Horror'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction', 'Horror', 'Dystopia'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction', 'Novel',
#        'Psychological novel'],
#       dtype='|S19')
#  array(['Fiction'],
#       dtype='|S7')
#  array(['Science Fiction', 'Speculative fiction', 'Fiction', 'Novel'],
#       dtype='|S19')
#  array(['Science Fiction'],
#       dtype='|S15')
#  array(['Science Fiction', 'Horror', 'Speculative fiction', 'Mystery',
#        'Epistolary novel', 'Fiction', 'Suspense'],
#       dtype='|S19')
#  array(['Speculative fiction', 'Fantasy', 'Fiction'],
#       dtype='|S19')
#  array(['Spy fiction', "Children's literature", 'Fiction'],
#       dtype='|S21')
#  array(['Crime Fiction', 'Detective fiction', 'Novel', 'Hardboiled'],
#       dtype='|S17')
#  array(['Science Fiction', 'Speculative fiction'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction', 'Fiction', 'Comic novel',
#        'Humour', 'Comic science fiction'],
#       dtype='|S21')
#  array(['Black comedy', 'Novel', 'Satire', 'Speculative fiction', 'Fiction'],
#       dtype='|S19')
#  array(['Speculative fiction', 'Dystopia'],
#       dtype='|S19')
#  array(['Autobiographical novel', 'Fiction'],
#       dtype='|S22')
#  array(['Speculative fiction', 'Fiction'],
#       dtype='|S19')
#  array(['Speculative fiction', 'Fantasy', "Children's literature"],
#       dtype='|S21')
#  array(['Fiction', 'Novel'],
#       dtype='|S7')
#  array(['Mystery', 'Historical novel'],
#       dtype='|S16')
#  array(['Crime Fiction', 'Mystery', 'Fiction', 'Suspense'],
#       dtype='|S13')
#  array(['Fiction', 'Romance novel'],
#       dtype='|S13')
#  array(["Children's literature", 'Fantasy', 'Speculative fiction', 'Humour',
#        'Fiction'],
#       dtype='|S21')
#  array(['Fantasy', 'Fiction', 'Novella'],
#       dtype='|S7')
#  array(['Speculative fiction', 'Fiction'],
#       dtype='|S19')
#  array(['Conspiracy fiction', 'Science Fiction', 'Philosophy',
#        'Adventure novel', 'Planetary romance', 'Fiction',
#        'Military science fiction'],
#       dtype='|S24')
#  array(['Science Fiction', 'Speculative fiction'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction', 'Fiction'],
#       dtype='|S19')
#  array(['Autobiographical novel'],
#       dtype='|S22')
#  array(['Roman a clef', 'Poetry', 'Fiction'],
#       dtype='|S12')
#  array(['Novel'],
#       dtype='|S5') array(['Fiction'],
#       dtype='|S7')
#  array(['Mystery', 'Fiction', 'Suspense'],
#       dtype='|S8')
#  array(['Lost World', 'Adventure novel'],
#       dtype='|S15')
#  array(['Fiction'],
#       dtype='|S7')
#  array(['Mystery', 'Hardboiled', 'Novel', 'Suspense', 'Fiction'],
#       dtype='|S10')
#  array(['Ghost story', 'Morality play', 'Novella', 'Speculative fiction',
#        'Fairy tale', 'Fiction'],
#       dtype='|S19')
#  array(['Fiction', 'Novel'],
#       dtype='|S7')
#  array(['Fiction', 'Novel'],
#       dtype='|S7')
#  array(['Science Fiction', 'Novella', 'Speculative fiction', 'Science',
#        'Fiction', 'Mathematics', 'Scientific romance'],
#       dtype='|S19')
#  array(['Novel'],
#       dtype='|S5')
#  array(['History', "Children's literature", 'Fiction', 'Romance novel',
#        'Novel'],
#       dtype='|S21')
#  array(['Fiction', 'Novel'],
#       dtype='|S7')
#  array(['War novel', 'Fiction'],
#       dtype='|S9')
#  array(['Spy fiction'],
#       dtype='|S11')
#  array(['Science Fiction', "Children's literature", 'Speculative fiction',
#        'Fantasy', 'Fiction', 'Bildungsroman'],
#       dtype='|S21')
#  array(['Science Fiction', 'Speculative fiction', 'Fantasy', 'Comedy',
#        'Comic novel', 'Fiction'],
#       dtype='|S19')
#  array(['Fantasy', 'Speculative fiction', 'Horror', "Children's literature"],
#       dtype='|S21')
#  array(['Fantasy', 'Fiction', 'Graphic novel'],
#       dtype='|S13')
#  array(['Vampire fiction', 'Horror', 'Speculative fiction', 'Fantasy',
#        'Fiction', 'Gothic fiction'],
#       dtype='|S19')
#  array(["Children's literature", 'Fiction', 'Novel'],
#       dtype='|S21')
#  array(['Alternate history', 'Speculative fiction'],
#       dtype='|S19')
#  array(['Novel'],
#       dtype='|S5')
#  array(['Fiction', 'Novel'],
#       dtype='|S7')
#  array(['Satire', 'Fiction', 'Novel'],
#       dtype='|S7')
#  array(['Novel'],
#       dtype='|S5')
#  array(['Lost World', 'Speculative fiction', 'Adventure novel'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction', 'Fiction'],
#       dtype='|S19')
#  array(['Romance novel', 'Fiction', 'Adventure novel', 'Historical novel'],
#       dtype='|S16')
#  array(['Science Fiction', 'Satire', 'Speculative fiction'],
#       dtype='|S19')
#  array(['Fiction', 'Novel'],
#       dtype='|S7')
#  array(['Adventure novel', 'Historical novel'],
#       dtype='|S16')
#  array(['Speculative fiction', 'Fiction'],
#       dtype='|S19')
#  array(['Speculative fiction'],
#       dtype='|S19')
#  array(['Thriller', 'Novel'],
#       dtype='|S8')
#  array(['Fiction', 'Novel'],
#       dtype='|S7')
#  array(['Science Fiction', 'Speculative fiction', 'Horror', 'Fiction'],
#       dtype='|S19')
#  array(['Fiction', 'Novel'],
#       dtype='|S7')
#  array(['Fiction'],
#       dtype='|S7')
#  array(['Science Fiction', 'Speculative fiction', 'Fantasy', 'Fiction'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction', 'Comedy', 'Fiction'],
#       dtype='|S19')
#  array(['War novel', 'Fiction'],
#       dtype='|S9')
#  array(['Horror', 'Speculative fiction', 'Ergodic literature',
#        'Romance novel', 'Satire', 'Fiction', 'Chivalric romance'],
#       dtype='|S19')
#  array(['Epistolary novel', 'Speculative fiction', 'Novella'],
#       dtype='|S19')
#  array(['Science Fiction', 'Speculative fiction', 'Fantasy', 'Fiction',
#        'Novel'],
#       dtype='|S19')
#  array(['War novel'],
#       dtype='|S9')
#  array(['Fiction', 'Novel'],
#       dtype='|S7')
#  array(['Autobiographical novel', 'K\\u00fcnstlerroman', 'Fiction'],
#       dtype='|S22')
#  array(['Novel', 'Speculative fiction', 'Mystery', 'Satire', 'Fiction',
#        'Black comedy', 'Autobiography', 'Suspense'],
#       dtype='|S19')
#  array(['Politics', 'Fiction'],
#       dtype='|S8')
#  array(['Science Fiction', 'Speculative fiction', 'Dystopia'],
#       dtype='|S19')
#  array(['Treatise', 'Non-fiction'],
#       dtype='|S11')
#  array(["Children's literature"],
#       dtype='|S21')
#  array(['Science Fiction', 'Speculative fiction', "Children's literature",
#        'Fiction'],
#       dtype='|S21')
#  array(['Speculative fiction', 'Comedy', 'Romance novel'],
#       dtype='|S19')
#  array(['Adventure', 'Adventure novel', 'Speculative fiction',
#        'Comic fantasy', 'Mystery', 'Fiction', 'Humour'],
#       dtype='|S19')
#  array(['Fiction', 'Novel'],
#       dtype='|S7')
#  array(['Comedy', 'Fiction'],
#       dtype='|S7')
#  array(['Novel', 'Satire', 'Historical fiction', 'Poetry', 'Fiction'],
#       dtype='|S18')]
